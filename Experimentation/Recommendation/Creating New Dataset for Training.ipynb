# %%
from bing_image_downloader import downloader

# %%
downloader.download("bad outfits full length", 
                    limit=10,  
                    output_dir='dataset', 
                    adult_filter_off=True, 
                    force_replace=False, 
                    timeout=60)
# Out:
# [%] Downloading Images to E:\USC\CourseWork\DSCI 551\Homework\Project\Experimentation\Recommendation\dataset\bad outfits full length
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://4.bp.blogspot.com/_5w7f_fyPBPw/S-EA5BGonyI/AAAAAAAAAdU/WKMdJZGjod4/s320/2149036836_3042097969.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://fashionbombdaily.com/wp-content/uploads/2017/02/fab-list-curvy-celebrities-on-the-red-carpet-oprah-winfrey-premiere-selma.jpg
# [!] Issue getting: https://fashionbombdaily.com/wp-content/uploads/2017/02/fab-list-curvy-celebrities-on-the-red-carpet-oprah-winfrey-premiere-selma.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123)>
# [%] Downloading Image #2 from https://i.dailymail.co.uk/i/newpix/2018/07/27/18/4E7F03F800000578-6000223-image-m-59_1532711737152.jpg
# ...

# %%
downloader.download("fashionable outfits full length men", 
                    limit=10,  
                    output_dir='dataset', 
                    adult_filter_off=True, 
                    force_replace=False, 
                    timeout=60)
# Out:
# [%] Downloading Images to E:\USC\CourseWork\DSCI 551\Homework\Project\Experimentation\Recommendation\dataset\fashionable outfits full length men
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/736x/24/0a/9a/240a9a28da45fc6847922959a52296a6--men-fashion-casual-latest-fashion-for-men.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/21/84/b7/2184b73589ed20bca40bfc826011eb01--fashion-fall-fashion-looks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/736x/62/a4/1f/62a41f0ea4da4411108b466026c92bb0--contemporary-style-the-day.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/70/b5/06/70b50607059f45cae22f6eaeb7851091--fashion-guide-mens-fashion.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://menscraze.com/wp-content/uploads/2016/05/Men-Boots-Fashion-Model.jpg
# [%] File Downloaded !
#
# ...
